# %% [markdown]
# # Machine Learning Foundations: Ep #1 - What is ML?
# https://www.youtube.com/watch?v=_Z9TRANg4c0&list=PLOU2XLYxmsII9mzQ-Xxug4l2o04JBrkLV&index=1&ab_channel=GoogleDevelopers

# %% [markdown]
# ## Lecture

# %% [markdown]
# Import the libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Define x and y

# %%
x = np.array([-1, 0, 1, 2, 3, 4], dtype=float)
y = 2*x-1

# %% [markdown]
# Define the model with `keras.Sequential()`
# - Define a sequence of layers
#
# Create a layer with `keras.layers.Dense()`
# - Dense is the simplest layer type

# %%
model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[1])]
)

model.compile(optimizer='sgd', loss='mse')

model.fit(x, y, epochs=1000)
# Out:
# Metal device set to: Apple M1 Pro
# Epoch 1/1000
# 1/1 [==============================] - 0s 139ms/step - loss: 34.5372
# Epoch 2/1000
# 2022-08-13 21:19:10.662576: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-13 21:19:10.662690: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-08-13 21:19:10.717682: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-08-13 21:19:10.816139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ...

# %% [markdown]
# Prediction

# %%
model.predict([10])
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 2022-08-13 21:19:16.446022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# array([[18.99988]], dtype=float32)

# %% [markdown]
# ## Exercise
#
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[1])
])

model.compile(optimizer='sgd', loss='mse')

xs = np.array([1, 2, 3, 4, 5, 6])
ys = xs * .5 + .5

model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 24.4085
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 11.3019
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.2357
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4281
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1286
# Epoch 6/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5271
# Epoch 7/1000
# 2022-08-13 21:19:16.574947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2487
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1198
# Epoch 9/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0601
# Epoch 10/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0324
# ...

# %%
model.predict([7.0])
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 2022-08-13 21:19:22.325255: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# array([[4.0035925]], dtype=float32)
