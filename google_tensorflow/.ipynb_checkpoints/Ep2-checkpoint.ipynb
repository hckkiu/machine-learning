# %% [markdown]
# # Machine Learning Foundations: Ep #2 - First steps in computer vision
# https://www.youtube.com/watch?v=j-35y1M9rRU&list=PLOU2XLYxmsII9mzQ-Xxug4l2o04JBrkLV&index=2&ab_channel=GoogleDevelopers

# %% [markdown]
# ## Lecture

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Normalize the images array as __neural network works best with values between 0 and 1__

# %%
train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# Use `keras.layers.Flatten()` to flatten images array, since each image has a dimension of 28x28

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)), 
    keras.layers.Dense(128, activation=tf.nn.relu), 
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=10)
# Out:
# 2022-08-12 22:32:19.491974: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-12 22:32:19.492557: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.4991 - accuracy: 0.8236
# Epoch 2/10
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.3734 - accuracy: 0.8644
# Epoch 3/10
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.3344 - accuracy: 0.8788
# Epoch 4/10
# ...

# %% [markdown]
# Evaluate the model

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
test_loss, test_acc
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %% [markdown]
# ## Exercise

# %%
import numpy as np
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()

x_train = x_train / 255
x_test = x_test / 255

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)), 
    tf.keras.layers.Dense(units=128, activation=tf.nn.relu), 
    tf.keras.layers.Dense(units=128, activation=tf.nn.softmax)
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 12s 193us/sample - loss: 0.3100 - accuracy: 0.9158
# Epoch 2/10
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.1338 - accuracy: 0.9607
# Epoch 3/10
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.0940 - accuracy: 0.9720
# Epoch 4/10
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.0699 - accuracy: 0.9791
# Epoch 5/10
# 60000/60000 [==============================] - 12s 198us/sample - loss: 0.0555 - accuracy: 0.9828
# Epoch 6/10
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.0435 - accuracy: 0.9868
# Epoch 7/10
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.0343 - accuracy: 0.9895
# Epoch 8/10
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.0289 - accuracy: 0.9908
# Epoch 9/10
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
test_loss, test_acc
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
